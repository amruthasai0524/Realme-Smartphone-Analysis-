# %%
import re
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from bs4 import BeautifulSoup
import requests
import warnings 
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("realme.csv")

# %%
data
# Out:
#                                            product name    price  ratings  \
# 0     realme P3 Lite 5G Charger in the Box (Purple B...  ₹10,499      4.4
# 1                 realme P3x 5G (Midnight Blue, 128 GB)  ₹11,999      4.4
# 2                 realme P3x 5G (Midnight Blue, 128 GB)  ₹12,999      4.4
# 3     realme P3 Lite 5G Charger in the Box (Midnight...  ₹11,499      4.4
# 4     realme P3 Lite 5G Charger in the Box (Midnight...  ₹10,499      4.4
# ...                                                 ...      ...      ...
# 9763                 realme P3 5G (Nebula Pink, 128 GB)  ₹15,999      4.4
# 9764          realme 14 Pro+ 5G (Emerald Drift, 256 GB)  ₹23,999      4.4
# 9765           realme P4 Pro 5G (Dark Oak Wood, 256 GB)  ₹28,999      4.4
# 9766                 realme 15x 5G (Maroon Red, 128 GB)  ₹17,499      4.4
# 9767                realme 15x 5G (Marine Blue, 128 GB)  ₹18,999      4.3
#
#                                                features  page number  \
# ...

# %%
data.columns
# Out:
# Index(['product name', 'price', 'ratings', 'features', 'page number',
#        'original_price', 'Discount', 'Review'],
#       dtype='object')

# %%
data.shape
# Out:
# (9768, 8)

# %%
data.info
# Out:
# <bound method DataFrame.info of                                            product name    price  ratings  \
# 0     realme P3 Lite 5G Charger in the Box (Purple B...  ₹10,499      4.4
# 1                 realme P3x 5G (Midnight Blue, 128 GB)  ₹11,999      4.4
# 2                 realme P3x 5G (Midnight Blue, 128 GB)  ₹12,999      4.4
# 3     realme P3 Lite 5G Charger in the Box (Midnight...  ₹11,499      4.4
# 4     realme P3 Lite 5G Charger in the Box (Midnight...  ₹10,499      4.4
# ...                                                 ...      ...      ...
# 9763                 realme P3 5G (Nebula Pink, 128 GB)  ₹15,999      4.4
# 9764          realme 14 Pro+ 5G (Emerald Drift, 256 GB)  ₹23,999      4.4
# 9765           realme P4 Pro 5G (Dark Oak Wood, 256 GB)  ₹28,999      4.4
# 9766                 realme 15x 5G (Maroon Red, 128 GB)  ₹17,499      4.4
# 9767                realme 15x 5G (Marine Blue, 128 GB)  ₹18,999      4.3
#
# ...

# %%
data.dtypes
# Out:
# product name       object
# price              object
# ratings           float64
# features           object
# page number         int64
# original_price     object
# Discount           object
# Review             object
# dtype: object

# %%
data.head(1)
# Out:
#                                         product name    price  ratings  \
# 0  realme P3 Lite 5G Charger in the Box (Purple B...  ₹10,499      4.4
#
#                                             features  page number  \
# 0  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB16...            1
#
#   original_price Discount                       Review
# 0        ₹12,999  19% off  5,420 Ratings & 229 Reviews

# %%
data["ratings"].value_counts()
# Out:
# ratings
# 4.4    7326
# 4.3    2442
# Name: count, dtype: int64

# %%
data["ratings"].fillna(data["ratings"].mode()[0],inplace = True)

# %%
data["Review"].fillna(data["Review"].mode()[0],inplace = True)

# %%
data["original_price"].fillna(data["original_price"].mode()[0],inplace = True)

# %%
data["Discount"].fillna(data["Discount"].mode()[0],inplace = True)

# %%
data["product name"][0]
# Out:
# 'realme P3 Lite 5G Charger in the Box (Purple Blossom, 128 GB)'

# %%
data["product name"].apply(lambda x:re.findall(r"\w+",x))
# Out:
# 0       [realme, P3, Lite, 5G, Charger, in, the, Box, ...
# 1              [realme, P3x, 5G, Midnight, Blue, 128, GB]
# 2              [realme, P3x, 5G, Midnight, Blue, 128, GB]
# 3       [realme, P3, Lite, 5G, Charger, in, the, Box, ...
# 4       [realme, P3, Lite, 5G, Charger, in, the, Box, ...
#                               ...
# 9763              [realme, P3, 5G, Nebula, Pink, 128, GB]
# 9764       [realme, 14, Pro, 5G, Emerald, Drift, 256, GB]
# 9765      [realme, P4, Pro, 5G, Dark, Oak, Wood, 256, GB]
# 9766              [realme, 15x, 5G, Maroon, Red, 128, GB]
# 9767             [realme, 15x, 5G, Marine, Blue, 128, GB]
# Name: product name, Length: 9768, dtype: object

# %%
import re 
data["features"].apply(lambda x:re.findall(r"\w+",x))
# Out:
# 0       [4, GB, RAM, 128, GB, ROM, Expandable, Upto, 2...
# 1       [6, GB, RAM, 128, GB, ROM17, 07, cm, 6, 72, in...
# 2       [8, GB, RAM, 128, GB, ROM17, 07, cm, 6, 72, in...
# 3       [6, GB, RAM, 128, GB, ROM, Expandable, Upto, 2...
# 4       [4, GB, RAM, 128, GB, ROM, Expandable, Upto, 2...
#                               ...
# 9763    [6, GB, RAM, 128, GB, ROM, Expandable, Upto, 2...
# 9764    [8, GB, RAM, 256, GB, ROM17, 35, cm, 6, 83, in...
# 9765    [12, GB, RAM, 256, GB, ROM17, 27, cm, 6, 8, in...
# 9766    [6, GB, RAM, 128, GB, ROM, Expandable, Upto, 2...
# 9767    [8, GB, RAM, 128, GB, ROM, Expandable, Upto, 2...
# Name: features, Length: 9768, dtype: object

# %%
data["Colour"] = data["product name"].str.extract(r'\((.*?),')[0]

# %%
data["Colour"]
# Out:
# 0       Purple Blossom
# 1        Midnight Blue
# 2        Midnight Blue
# 3        Midnight Lily
# 4        Midnight Lily
#              ...
# 9763       Nebula Pink
# 9764     Emerald Drift
# 9765     Dark Oak Wood
# 9766        Maroon Red
# 9767       Marine Blue
# Name: Colour, Length: 9768, dtype: object

# %%
data.head(1)
# Out:
#                                         product name    price  ratings  \
# 0  realme P3 Lite 5G Charger in the Box (Purple B...  ₹10,499      4.4
#
#                                             features  page number  \
# 0  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB16...            1
#
#   original_price Discount                       Review  price1  \
# 0        ₹12,999  19% off  5,420 Ratings & 229 Reviews   10499
#
#    original_lprice GB_list        Review-1  number_of_ratings      Ratings1  \
# 0            12999   ['8']  5,420 Ratings                   5   229 Reviews
#
#    number_of_reviews          Colour
# 0                229  Purple Blossom

# %%
data["Colour"].value_counts()
# Out:
# Colour
# Marine Blue       1221
# Purple Blossom     814
# Midnight Blue      814
# Midnight Lily      814
# Onyx Black         814
# Crystal Purple     814
# Stellar Pink       407
# Engine Blue        407
# Steel Grey         407
# Flowing Silver     407
# Silk Purple        407
# Nebula Pink        407
# Midnight Ivy       407
# Maroon Red         407
# Velvet Green       407
# Emerald Drift      407
# Dark Oak Wood      407
# Name: count, dtype: int64

# %%
data["features"].apply(lambda x:re.findall(r"\w+",x))
# Out:
# 0       [4, GB, RAM, 128, GB, ROM, Expandable, Upto, 2...
# 1       [6, GB, RAM, 128, GB, ROM17, 07, cm, 6, 72, in...
# 2       [8, GB, RAM, 128, GB, ROM17, 07, cm, 6, 72, in...
# 3       [6, GB, RAM, 128, GB, ROM, Expandable, Upto, 2...
# 4       [4, GB, RAM, 128, GB, ROM, Expandable, Upto, 2...
#                               ...
# 9763    [6, GB, RAM, 128, GB, ROM, Expandable, Upto, 2...
# 9764    [8, GB, RAM, 256, GB, ROM17, 35, cm, 6, 83, in...
# 9765    [12, GB, RAM, 256, GB, ROM17, 27, cm, 6, 8, in...
# 9766    [6, GB, RAM, 128, GB, ROM, Expandable, Upto, 2...
# 9767    [8, GB, RAM, 128, GB, ROM, Expandable, Upto, 2...
# Name: features, Length: 9768, dtype: object

# %%
data["RAM"] = data["features"].apply(lambda x:re.findall(r"\w+",x)[0])

# %%
data["RAM"]
# Out:
# 0        4
# 1        6
# 2        8
# 3        6
# 4        4
#         ..
# 9763     6
# 9764     8
# 9765    12
# 9766     6
# 9767     8
# Name: RAM, Length: 9768, dtype: object

# %%
data.head(1)
# Out:
#                                         product name    price  ratings  \
# 0  realme P3 Lite 5G Charger in the Box (Purple B...  ₹10,499      4.4
#
#                                             features  page number  \
# 0  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB16...            1
#
#   original_price Discount                       Review  price1  \
# 0        ₹12,999  19% off  5,420 Ratings & 229 Reviews   10499
#
#    original_lprice GB_list        Review-1  number_of_ratings      Ratings1  \
# 0            12999   ['8']  5,420 Ratings                   5   229 Reviews
#
#    number_of_reviews          Colour RAM
# 0                229  Purple Blossom   4

# %%
data["RAM"].value_counts()
# Out:
# RAM
# 6     4070
# 8     3256
# 4     1628
# 12     814
# Name: count, dtype: int64

# %%
data["ROM"] = data["features"].apply(lambda x:re.findall(r"\w+",x)[0])

# %%
data["features"].apply(lambda x:re.findall(r"\w+",x)[0])
# Out:
# 0        4
# 1        6
# 2        8
# 3        6
# 4        4
#         ..
# 9763     6
# 9764     8
# 9765    12
# 9766     6
# 9767     8
# Name: features, Length: 9768, dtype: object

# %%
data["ROM"].value_counts().head(10)
# Out:
# ROM
# 6     4070
# 8     3256
# 4     1628
# 12     814
# Name: count, dtype: int64

# %%
data.head(1)
# Out:
#                                         product name    price  ratings  \
# 0  realme P3 Lite 5G Charger in the Box (Purple B...  ₹10,499      4.4
#
#                                             features  page number  \
# 0  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB16...            1
#
#   original_price Discount                       Review  price1  \
# 0        ₹12,999  19% off  5,420 Ratings & 229 Reviews   10499
#
#    original_lprice GB_list        Review-1  number_of_ratings      Ratings1  \
# 0            12999   ['8']  5,420 Ratings                   5   229 Reviews
#
#    number_of_reviews          Colour RAM ROM
# 0                229  Purple Blossom   4   4

# %%
data["Review-1"] = data["Review"].apply(lambda x:re.findall(r"\w+",x))

# %%
data["Review-1"]
# Out:
# 0           [5, 420, Ratings, 229, Reviews]
# 1       [64, 413, Ratings, 2, 409, Reviews]
# 2          [21, 314, Ratings, 880, Reviews]
# 3           [7, 721, Ratings, 314, Reviews]
# 4           [5, 420, Ratings, 229, Reviews]
#                        ...
# 9763    [31, 233, Ratings, 1, 992, Reviews]
# 9764    [15, 668, Ratings, 1, 877, Reviews]
# 9765        [3, 090, Ratings, 268, Reviews]
# 9766        [2, 742, Ratings, 204, Reviews]
# 9767        [2, 198, Ratings, 159, Reviews]
# Name: Review-1, Length: 9768, dtype: object

# %%
data.head(1)
# Out:
#                                         product name    price  ratings  \
# 0  realme P3 Lite 5G Charger in the Box (Purple B...  ₹10,499      4.4
#
#                                             features  page number  \
# 0  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB16...            1
#
#   original_price Discount                       Review  price1  \
# 0        ₹12,999  19% off  5,420 Ratings & 229 Reviews   10499
#
#    original_lprice GB_list                         Review-1
# 0            12999   ['8']  [5, 420, Ratings, 229, Reviews]

# %%
data["Review-1"] = data["Review"].apply(lambda x:re.split(r"[&]",x)[0])
data["number_of_ratings"]= data["Review-1"].apply(lambda x:re.findall(r"[\d]+",x)[0].replace(",",""))

# %%
data["number_of_ratings"]
# Out:
# 0        5
# 1       64
# 2       21
# 3        7
# 4        5
#         ..
# 9763    31
# 9764    15
# 9765     3
# 9766     2
# 9767     2
# Name: number_of_ratings, Length: 9768, dtype: object

# %%
data.head(1)
# Out:
#                                         product name    price  ratings  \
# 0  realme P3 Lite 5G Charger in the Box (Purple B...  ₹10,499      4.4
#
#                                             features  page number  \
# 0  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB16...            1
#
#   original_price Discount                       Review  price1  \
# 0        ₹12,999  19% off  5,420 Ratings & 229 Reviews   10499
#
#    original_lprice GB_list        Review-1 number_of_ratings
# 0            12999   ['8']  5,420 Ratings                  5

# %%
data["Ratings1"]= data["Review"].apply(lambda x:re.split(r"[&]",x)[1])
data["number_of_reviews"]= data["Ratings1"].apply(lambda x:re.findall(r"[\d,]+",x)[0].replace(",","")).astype("int")

# %%
data["number_of_reviews"]
# Out:
# 0        229
# 1       2409
# 2        880
# 3        314
# 4        229
#         ...
# 9763    1992
# 9764    1877
# 9765     268
# 9766     204
# 9767     159
# Name: number_of_reviews, Length: 9768, dtype: int64

# %%
data.head(1)
# Out:
#                                         product name    price  ratings  \
# 0  realme P3 Lite 5G Charger in the Box (Purple B...  ₹10,499      4.4
#
#                                             features  page number  \
# 0  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB16...            1
#
#   original_price Discount                       Review  price1  \
# 0        ₹12,999  19% off  5,420 Ratings & 229 Reviews   10499
#
#    original_lprice GB_list        Review-1 number_of_ratings      Ratings1  \
# 0            12999   ['8']  5,420 Ratings                  5   229 Reviews
#
#    number_of_reviews
# 0                229

# %%
import pandas as pd

# %%
data = pd.read_csv("realme.csv")

# %%
data.head(1)
# Out:
#                                         product name    price  ratings  \
# 0  realme P3 Lite 5G Charger in the Box (Purple B...  ₹10,499      4.4
#
#                                             features  page number  \
# 0  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB16...            1
#
#   original_price Discount                       Review  price1  \
# 0        ₹12,999  19% off  5,420 Ratings & 229 Reviews   10499
#
#    original_lprice GB_list        Review-1  number_of_ratings      Ratings1  \
# 0            12999   ['8']  5,420 Ratings                   5   229 Reviews
#
#    number_of_reviews          Colour RAM ROM
# 0                229  Purple Blossom   4   4

# %%
data.shape
# Out:
# (9768, 18)

# %%
data["price1"] = data["price"].apply(lambda x:int(re.sub(r"[₹,]","",str(x))))

# %%
data["original_lprice"] = data["original_price"].apply(lambda x: int(re.sub(r"[₹,]","",str(x))))

# %%
data.shape
# Out:
# (9768, 18)

# %%
data.head(1)
# Out:
#                                         product name    price  ratings  \
# 0  realme P3 Lite 5G Charger in the Box (Purple B...  ₹10,499      4.4
#
#                                             features  page number  \
# 0  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB16...            1
#
#   original_price Discount                       Review  price1  \
# 0        ₹12,999  19% off  5,420 Ratings & 229 Reviews   10499
#
#    original_lprice GB_list        Review-1  number_of_ratings      Ratings1  \
# 0            12999   ['8']  5,420 Ratings                   5   229 Reviews
#
#    number_of_reviews          Colour RAM ROM
# 0                229  Purple Blossom   4   4

# %%
data["GB_list"] = data["product name"].apply(lambda x:re.findall(r"(\d)\s*GB",x))

# %%
data["product name"].apply(lambda x:re.findall(r"(\d+)\s*GB",x))
# Out:
# 0       [128]
# 1       [128]
# 2       [128]
# 3       [128]
# 4       [128]
#         ...
# 9763    [128]
# 9764    [256]
# 9765    [256]
# 9766    [128]
# 9767    [128]
# Name: product name, Length: 9768, dtype: object

# %%
data.shape
# Out:
# (9768, 18)

# %%
data.to_csv("cleaned_realme.csv",index = False)

# %%
data = pd.read_csv("cleaned_realme.csv")

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.isnull().sum()
# Out:
# product name         0
# price                0
# ratings              0
# features             0
# page number          0
# original_price       0
# Discount             0
# Review               0
# price1               0
# original_lprice      0
# GB_list              0
# Review-1             0
# number_of_ratings    0
# Ratings1             0
# number_of_reviews    0
# Colour               0
# RAM                  0
# ROM                  0
# dtype: int64

# %%
col = "price1"
